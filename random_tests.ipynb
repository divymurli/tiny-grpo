# %%
import torch

# %%
# %pip install -e .
# Out:
# Obtaining file:///Users/divyanshumurli/Software/tiny-grpo
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /Users/divyanshumurli/anaconda3/envs/pytorch/lib/python3.12/site-packages (from tiny-grpo==0.1.0) (2.8.0)
# Requirement already satisfied: filelock in /Users/divyanshumurli/anaconda3/envs/pytorch/lib/python3.12/site-packages (from torch->tiny-grpo==0.1.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/divyanshumurli/anaconda3/envs/pytorch/lib/python3.12/site-packages (from torch->tiny-grpo==0.1.0) (4.15.0)
# Requirement already satisfied: setuptools in /Users/divyanshumurli/anaconda3/envs/pytorch/lib/python3.12/site-packages (from torch->tiny-grpo==0.1.0) (69.5.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/divyanshumurli/anaconda3/envs/pytorch/lib/python3.12/site-packages (from torch->tiny-grpo==0.1.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/divyanshumurli/anaconda3/envs/pytorch/lib/python3.12/site-packages (from torch->tiny-grpo==0.1.0) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/divyanshumurli/anaconda3/envs/pytorch/lib/python3.12/site-packages (from torch->tiny-grpo==0.1.0) (3.1.4)
# Requirement already satisfied: fsspec in /Users/divyanshumurli/anaconda3/envs/pytorch/lib/python3.12/site-packages (from torch->tiny-grpo==0.1.0) (2024.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/divyanshumurli/anaconda3/envs/pytorch/lib/python3.12/site-packages (from sympy>=1.13.3->torch->tiny-grpo==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/divyanshumurli/anaconda3/envs/pytorch/lib/python3.12/site-packages (from jinja2->torch->tiny-grpo==0.1.0) (2.1.3)
# Building wheels for collected packages: tiny-grpo
#   Building editable for tiny-grpo (pyproject.toml) ... done
#   Created wheel for tiny-grpo: filename=tiny_grpo-0.1.0-0.editable-py3-none-any.whl size=1272 sha256=6b0f252ecfbe1b11cd492a320657ef55c464a22c4f9a6ab576046b93a09fde81
#   Stored in directory: /private/var/folders/_p/xfyndqdx57zbwcs2fc4dqxlr0000gn/T/pip-ephem-wheel-cache-jn0u85_b/wheels/6a/76/90/e1b6600ece6c70233ad8c5c707931d9794f580996045fa1b1e
# Successfully built tiny-grpo
# Installing collected packages: tiny-grpo
#   Attempting uninstall: tiny-grpo
#     Found existing installation: tiny-grpo 0.1.0
#     Uninstalling tiny-grpo-0.1.0:
#       Successfully uninstalled tiny-grpo-0.1.0
# Successfully installed tiny-grpo-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from tiny_grpo.data import ParityDataset, make_parity_loader
from tiny_grpo.tokenizer import TinyTokenizer

# %%
dataset = ParityDataset(size=12)

# %%
dataset.__getitem__(10)
# Out:
# DigitExample(digit=0)

# %%
tokenizer = TinyTokenizer()

# %%
tokenizer.vocab_size
# Out:
# 15

# %%
loader = make_parity_loader(
    tokenizer=tokenizer,
    batch_size=2,
    device="cpu",
    dataset_size=16
)

# %%
for batch in loader:
    print(batch)
# Out:
# {'prompts': tensor([[1, 8],
#         [1, 4]]), 'digits': tensor([5, 1])}
# {'prompts': tensor([[ 1,  6],
#         [ 1, 10]]), 'digits': tensor([3, 7])}
# {'prompts': tensor([[1, 4],
#         [1, 3]]), 'digits': tensor([1, 0])}
# {'prompts': tensor([[1, 6],
#         [1, 5]]), 'digits': tensor([3, 2])}
# {'prompts': tensor([[ 1,  9],
#         [ 1, 12]]), 'digits': tensor([6, 9])}
# {'prompts': tensor([[1, 3],
#         [1, 8]]), 'digits': tensor([0, 5])}
# {'prompts': tensor([[1, 7],
#         [1, 7]]), 'digits': tensor([4, 4])}
# {'prompts': tensor([[ 1,  5],
#         [ 1, 11]]), 'digits': tensor([2, 8])}
